# %% [markdown]
# <a href="https://colab.research.google.com/github/Anuradha1708/SD_Anuradha_0065/blob/main/project3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
balance=5000
pin=1909
p=int(input("Enter the PIN:"))
if p==pin:
  amount=int(input("Enter the amount to be withdrawl:"))
  balance=balance-amount
  print("Your balance is",balance)
else:
  print("Invalid PIN")
# Out:
# Enter the PIN:1909
# Enter the amount to be withdrawl:2000
# Your balance is 3000

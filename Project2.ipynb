# %% [markdown]
# <a href="https://colab.research.google.com/github/Anuradha1708/SD_Anuradha_0065/blob/main/Project2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Project 2

# %%
print("======Students Marksheet=====")
name = input("Enter student name:")
subject1=int(input("enter maths marks:"))
subject2=int(input("enter english marks:"))
subject3=int(input("enter hindi marks:"))
total_marks=(subject1+subject2+subject3)
percentage=total_marks/300*1006
print(f"Your cgpa is {percentage/9.5} ")
def grade(marks):
    if marks >= 90:
        return "A"
    elif marks >= 75:
        return "B"
    elif marks >= 60:
        return "C"
    elif marks >= 40:
        return "D"
    else:
        return "E"
print("maths Marks and Grade:",subject1, grade(subject1))
print("english Marks and Grade:",subject2, grade(subject2))
print("hindi6 Marks and Grade:",subject3, grade(subject3))
# Out:
# ======Students Marksheet=====
# Enter student name:anu
# enter maths marks:50
# enter english marks:0
# enter hindi marks:70
# Your cgpa is 4.2105263157894735
# maths Marks and Grade: 50 D
# english Marks and Grade: 0 E
# hindi6 Marks and Grade: 70 C

# %% [markdown]
# <a href="https://colab.research.google.com/github/Anuradha1708/SD_Anuradha_0065/blob/main/Day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
l=[1,2,3,4]

# %%
ar=np.array(l)

# %%
ar
# Out:
# array([1, 2, 3, 4])

# %%
type(ar)
# Out:
# numpy.ndarray

# %%
np.array([[1,2],[3,4]])
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
np.asarray(l)
# Out:
# array([1, 2, 3, 4])

# %%
a=[2,3,4]

# %%
np.asanyarray(a)
# Out:
# array([2, 3, 4])

# %%
b=np.matrix(l)

# %%
b
# Out:
# matrix([[1, 2, 3, 4]])

# %% [markdown]
# # ***Pandas***

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('/content/weather.csv')

# %%
df.loc[0:5,["MinTemp","MaxTemp","Rainfall"]]
# Out:
#    MinTemp  MaxTemp  Rainfall
# 0      8.0     24.3       0.0
# 1     14.0     26.9       3.6
# 2     13.7     23.4       3.6
# 3     13.3     15.5      39.8
# 4      7.6     16.1       2.8
# 5      6.2     16.9       0.0

# %%
df
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
df.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df.sample(5)
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 123      8.3     27.3       0.0          5.6      10.1           E
# 248     -0.6     14.0       0.0          1.2       7.1          NW
# 241      1.2     16.0       0.0          1.4       6.1         NNW
# 34      14.5     21.8       0.0          8.4       9.8         ENE
# 10       9.1     25.2       0.0          4.2      11.9           N
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 123           35.0        ESE        WNW           6.0  ...           28
# 248           41.0        WNW        NNW           2.0  ...           59
# 241           31.0          S          N           6.0  ...           38
# 34            43.0        ESE          E          11.0  ...           63
# 10            30.0         SE         NW           6.0  ...           34
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# ...

# %%
df.shape
# Out:
# (366, 22)

# %%
df["MinTemp"]
# Out:
# 0       8.0
# 1      14.0
# 2      13.7
# 3      13.3
# 4       7.6
#        ...
# 361     9.0
# 362     7.1
# 363    12.5
# 364    12.5
# 365    12.3
# Name: MinTemp, Length: 366, dtype: float64

# %%
df.iloc[0]
# Out:
# MinTemp             8.0
# MaxTemp            24.3
# Rainfall            0.0
# Evaporation         3.4
# Sunshine            6.3
# WindGustDir          NW
# WindGustSpeed      30.0
# WindDir9am           SW
# WindDir3pm           NW
# WindSpeed9am        6.0
# WindSpeed3pm         20
# Humidity9am          68
# Humidity3pm          29
# Pressure9am      1019.7
# Pressure3pm      1015.0
# Cloud9am              7
# Cloud3pm              7
# Temp9am            14.4
# Temp3pm            23.6
# RainToday            No
# RISK_MM             3.6
# RainTomorrow        Yes
# Name: 0, dtype: object

# %%
df.iloc[0:10]
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
# 5      6.2     16.9       0.0          5.8       8.2          SE
# 6      6.1     18.2       0.2          4.2       8.4          SE
# 7      8.3     17.0       0.0          5.6       4.6           E
# 8      8.8     19.5       0.0          4.0       4.1           S
# 9      8.4     22.8      16.2          5.4       7.7           E
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# ...

# %%
df.iloc[:,0:5]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine
# 0        8.0     24.3       0.0          3.4       6.3
# 1       14.0     26.9       3.6          4.4       9.7
# 2       13.7     23.4       3.6          5.8       3.3
# 3       13.3     15.5      39.8          7.2       9.1
# 4        7.6     16.1       2.8          5.6      10.6
# ..       ...      ...       ...          ...       ...
# 361      9.0     30.7       0.0          7.6      12.1
# 362      7.1     28.4       0.0         11.6      12.7
# 363     12.5     19.9       0.0          8.4       5.3
# 364     12.5     26.9       0.0          5.0       7.1
# 365     12.3     30.2       0.0          6.0      12.6
#
# [366 rows x 5 columns]

# %%
df[df["MaxTemp"]<30]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 359      3.3     25.5       0.0          5.2      10.8           N
# 360      7.9     26.1       0.0          6.8       3.5         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
plt.figure(figsize=(8,5))
plt.hist(df["MaxTemp"], bins=20)
plt.title("Distribution of Maxmum Temprature")
plt.xlabel("Maxmum Temprature")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

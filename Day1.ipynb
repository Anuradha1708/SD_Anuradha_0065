# %% [markdown]
# <a href="https://colab.research.google.com/github/Anuradha1708/SD_Anuradha_0065/blob/main/Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1+1
# Out:
# 2

# %%
a=10;

# %%
b=40

# %%
type(b)
# Out:
# int

# %%
y=9.7
type(y)
# Out:
# float

# %%
print("hello")
# Out:
# hello

# %%
q=89

# %%
t=90

# %%
print(q+t)
# Out:
# 179

# %%
r=3.5
type(r)
# Out:
# float

# %%
s="anu"
type(s)
# Out:
# str

# %%
s[0]
# Out:
# 'a'

# %%
s[1]
# Out:
# 'n'

# %%
s[2]
# Out:
# 'u'

# %%
s[-3]
# Out:
# 'a'

# %%
s[-2]
# Out:
# 'n'

# %%
s="srmcem"
s[0:3:-5]
# Out:
# ''

# %%
True/False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_1067/2794436645.py in <cell line: 0>()
# ----> 1 True/False
#
# ZeroDivisionError: division by zero

# %%
False/True
# Out:
# 0.0

# %%
t="Batch name is Computer Science & engineering"

# %%
t[0:44:7]
# Out:
# 'BaCrcgn'

# %%
t[-3:-44:-5]
# Out:
# 'ii&ermina'

# %% [markdown]
# list

# %%
l=[3,4,54,"anu",4.5,3+5j]

# %%
l[0]
# Out:
# 3

# %%
l[5].real
# Out:
# 3.0

# %%
l[5].imag
# Out:
# 5.0

# %%
type(l)
# Out:
# list

# %%
type(l[5])
# Out:
# complex

# %%
type(l[2])
# Out:
# int

# %%
s="ramswar oop"

# %%
s.count('o')
# Out:
# 2

# %%
s.count(' ')
# Out:
# 1

# %%
s.find('a')
# Out:
# 1

# %%
s.lower()
# Out:
# 'ramswar oop'

# %%
s.upper()
# Out:
# 'RAMSWAR OOP'

# %%
len(s)
# Out:
# 11

# %%
l[::-1]
# Out:
# [(3+5j), 4.5, 'anu', 54, 4, 3]

# %%
l
# Out:
# [3, 4, 54, 'anu', 4.5, (3+5j)]

# %%
l.append(67)

# %%
l
# Out:
# [3, 4, 54, 'anu', 4.5, (3+5j), 67]

# %%
l.pop()
# Out:
# 67

# %%
l.pop()
# Out:
# (3+5j)

# %%
l.insert(0,56)

# %%
l
# Out:
# [56, 3, 4, 54, 'anu', 4.5]

# %% [markdown]
# tuple

# %%
t=(2,4,5,4.7,5,"anu")

# %%
t[0]
# Out:
# 2

# %%
t[1]
# Out:
# 4

# %%
t.count(5)
# Out:
# 2

# %%
len(t[5])
# Out:
# 3

# %%
len(t)
# Out:
# 6

# %% [markdown]
# dictonary

# %%
dict={"name":'age',"ramesh":45,"kamlesh":34}

# %%
dict['name']
# Out:
# 'age'

# %%
dict['ramesh']
# Out:
# 45

# %%
len(dict)
# Out:
# 3

# %%
l.remove(3)

# %%
l
# Out:
# [56, 4, 54, 'anu', 4.5]
